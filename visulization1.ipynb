# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\C_v\\Desktop\\SampleSensordata.csv")

# %%
df.head()
# Out:
#      DateTimeStamp    Temp  SensorX  SensorY  Mode  MotorA  MotorB
# 0  9/16/2019 10:10  219.08     7.50     3.15     0       0       0
# 1  9/16/2019 11:10  219.10     7.75     2.96     0       0       0
# 2  9/16/2019 12:10  219.47     7.55     3.05     0       0       0
# 3  9/16/2019 13:10  219.27     7.55     3.02     0       0       0
# 4  9/16/2019 14:10  219.27     7.80     2.89     0       0       0

# %%
df=df.dropna()

# %%
#df.NewMotorvalue=df.NewMotorvalue.astype(int)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl


fig, ax1 = plt.subplots()
plt.xlabel('Date Time')
plt.ylabel("Sensorx,SensorY,MortorA,MortorB")


plt.title("Please tell it to me the title")

plt.grid(color='black')



ax1.plot(df.DateTimeStamp,df['SensorX'] ,color='red',label='SensorX')
ax1.plot(df.DateTimeStamp,df['SensorY'] ,color='green',label='SensorY')
ax1.plot(df.DateTimeStamp,df['MotorA'] ,color='brown',label='MotorA')
ax1.plot(df.DateTimeStamp,df['MotorB'] ,color='indigo',label='MotorB')

plt.legend(loc='upper left')

ax2 = ax1.twinx()

ax2.plot(df.DateTimeStamp, df.Temp,color='b',label='Temperature')
plt.ylabel("Temperature")
plt.legend(loc='upper right')
fig.autofmt_xdate(rotation=45)


plt.xticks(np.arange(0, 105, 3)) 

plt.rcParams['figure.figsize'] = 15,10

plt.savefig("C:\\Users\\C_v\\Desktop\\chart1.png")

# %%
fig, (ax1,ax3) = plt.subplots(2)
plt.xlabel('Date Time')
plt.ylabel("MortorA,MortorB")
plt.grid(color='black')


plt.title("Please tell it to me the title")
plt.xticks(np.arange(0, 105, 3)) 
fig.autofmt_xdate(rotation=45)





ax1.plot(df.DateTimeStamp,df['SensorX'] ,color='red',label='SensorX')
ax1.plot(df.DateTimeStamp,df['SensorY'] ,color='green',label='SensorY')
plt.grid(color='black')
ax2 = ax1.twinx()

ax2.plot(df.DateTimeStamp, df.Temp,color='b',label='Temperature')
plt.ylabel("Temperature")


plt.xticks(np.arange(0, 105, 3)) 
plt.grid(color='black')
plt.rcParams['figure.figsize'] = 15,10




ax3.plot(df.DateTimeStamp,df['MotorA'] ,color='blue',label='MotorA')
ax3.plot(df.DateTimeStamp,df['MotorB'] ,color='red',label='MotorB')



#plt.savefig("C:\\Users\\C_v\\Desktop\\chart2.png")
